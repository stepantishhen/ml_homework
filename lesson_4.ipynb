# %%
import librosa
from PIL.Image import Image

# %%
file = 'pesenka.wav'
signal, sr = librosa.load(file)

# %%
signal, sr = librosa.load(file)

# %%
len(signal)
# Out:
# 3092544

# %%
sr
# Out:
# 22050

# %%
signal.shape
# Out:
# (3092544,)

# %%
import matplotlib.pyplot as plt
import librosa.display as ld

# %%
plt.figure(figsize=(14, 5))
ld.waveshow(y=signal, sr=sr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 plt.figure(figsize=(14, 5))
# ----> 2 ld.waveshow(y=signal, sr=sr)
#
# File ~/PycharmProjects/ml/.venv/lib/python3.10/site-packages/librosa/display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.3'

# %%
X = librosa.stft(signal)
s = librosa.amplitude_to_db(abs(X))
ld.specshow(s, sr=sr, x_axis = 'time', y_axis='linear')
plt.colorbar()

# %%
import librosa
librosa.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#
# librosa: 0.10.1
#
# audioread: 3.0.1
# numpy: 1.26.4
# scipy: 1.12.0
# sklearn: 1.4.1.post1
# joblib: 1.3.2
# decorator: 5.1.1
# numba: 0.59.1
# soundfile: 0.12.1
# pooch: v1.8.1
# soxr: 0.3.7
# typing_extensions: installed, no version number available
# lazy_loader: installed, no version number available
# msgpack: 1.0.8
#
# numpydoc: None
# sphinx: None
# sphinx_rtd_theme: None
# matplotlib: 3.8.3
# sphinx_multiversion: None
# sphinx_gallery: None
# mir_eval: None
# ipython: None
# sphinxcontrib.rsvgconverter: None
# pytest: None
# pytest_mpl: None
# pytest_cov: None
# samplerate: None
# resampy: None
# presets: None
# packaging: 23.2

# %%
fig, ax = plt.subplots()
librosa.display.waveshow(signal, sr=sr, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 librosa.display.waveshow(signal, sr=sr, ax=ax)
#
# File ~/PycharmProjects/ml/.venv/lib/python3.10/site-packages/librosa/display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'

# %%
plt.figure(figsize=(14, 5))
ld.waveshow(y=signal, sr=sr)

# %%
from PIL import  Image
file = 'img.png'

with Image.open(file) as img:
    img.load()
    print(img.getpixel([1, 1]))
    img.show()
# Out:
# (160, 157, 151, 255)
